# %%
import pickle

# %%
loaded_model = pickle.load(open("final_modal_multi_linear.sav",'rb'))
result = loaded_model.predict([[1000 , 2000 , 35000 , 0 , 1]])
# Out:
# C:\Anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
result
# Out:
# array([[44645.42431399]])

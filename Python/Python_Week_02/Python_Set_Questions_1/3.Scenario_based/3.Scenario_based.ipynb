# %%
1.Scenario: A system checks if a user is eligible to vote based on their age.
 Write logic to ask the user for their age and determine if they are eligible to vote 
based on whether they are 18 or older.

Logic:     
1. input() → asks the user to enter their age.
2. int() → converts the input from string to integer.
3. if age >= 18 → checks if the age is 18 or more.
4. If true → prints eligible to vote.
5. If false → prints not eligible to vote.

# %%
2.Scenario: A program processes a list of numbers and needs to find the largest value.
 Write logic to identify and return the largest number from a given list.

Logic : 
1. numbers → list of numbers.
2. largest = numbers[0] → assume the first number is the largest.
3. for num in numbers → check each number in the list.
4. if num > largest → if current number is bigger, update largest.
5. Finally print the largest value.

# %%
3. Scenario: A company provides employees with a 10% bonus if their salary exceeds $50,000.
Write logic to determine the bonus amount based on the given salary.  

Logic : 
1. input() → asks the user to enter the salary.
2. float() → converts the input into a number.
3. if salary > 50000 → checks if salary is more than 50,000.
4. If true → calculate 10% bonus using salary * 0.10.
5. If false → print no bonus.

# %%
4.Scenario: A program evaluates a number to determine if it is even or odd.
 Write logic to check whether a given number is even or odd.

Logic:     
1. input() → asks the user to enter a number.
2. int() → converts the input to an integer.
3. number % 2 → finds the remainder when divided by 2.
4. If remainder is 0 → Even number.
5. If remainder is not 0 → Odd number.

# %%
5.Scenario: A text-processing tool reverses a given word or sentence for formatting purposes.
 Write logic to take a word or sentence as input and produce its reversed version.

Logic : 
1.input() → takes a word or sentence from the user.
2.reversed_text = "" → empty string to store reversed result.
3. for char in text → goes through each character.
4.char + reversed_text → adds the new character in front, which reverses the order.
5.Finally prints the reversed text.

# %%
6.Scenario: A grading system determines whether a student has passed or failed based on their score.
 Write logic to check if a student has passed a subject by scoring at least 40 marks.

# %%
7.Scenario: A retail store offers a 20% discount if a customer’s total order exceeds $100. 
Write logic to calculate the final amount to be paid after applying the discount.

Logic : 
1.input() → asks the student to enter marks.
2.int() → converts the input into an integer.
3.if marks >= 40 → checks if marks are 40 or more.
4.If true → student passes.
5.If false → student fails.

# %%
8.Scenario: A banking system processes withdrawal requests and ensures the user has enough balance.
Write logic to check if a user has enough balance before allowing a withdrawal and update the 
remaining balance accordingly.

Logic : 
1.balance → user’s current account balance.
2.withdraw → amount the user wants to withdraw.
3.if withdraw <= balance → checks if enough balance is available.
4.If true → subtract withdrawal amount from balance.
5.Print the remaining balance.
6.If false → show Insufficient balance.

# %%
9.Scenario: A calendar system verifies whether a given year is a leap year based on standard leap
year rules. Write logic to determine whether a given year is a leap year.

Logic : 
1.Get the year from the user using input() and convert it to an integer.
2.Check the leap year conditions:
    * If the year is divisible by 4 AND not divisible by 100, it is a leap year.
    * OR if the year is divisible by 400, it is also a leap year.
3.If the condition is true, print "It is a Leap Year".
4.Otherwise, print "It is not a Leap Year".

# %%
10 . Scenario: A program filters out only even numbers from a given list.
 Write logic to extract and return only the even numbers from a list.

Logic : 
1.Create a list of numbers.
2.Create an empty list to store even numbers.
3.Use a for loop to check each number in the list.
4.If num % 2 == 0, the number is even.
5.Add the even number to the new list using append().
6.Print the list of even numbers.

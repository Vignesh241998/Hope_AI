# %%
# If
if():
    print()

# %%
age=int(input("Enter AGE : "))
# Out:
# Enter AGE :  18

# %%
if(age==18):
    print(f"Success -> Person's Age is {age}")
# Out:
# Success -> Person's Age is 18

# %%
# If-Else 

if():
    print()
else:
    print()

# %%
if(age<18):
    print("Low age")
else:
    print("Correct Age")
# Out:
# Correct Age

# %%
# If-Elif 

person_age = int(input("Enter your age:"))
# Out:
# Enter your age: 27

# %%
print(f"Your Age is -> {age}")
if(age<18):
    print("Children")
elif(age<35):
    print("Adult")
elif(age<57):
    print("Citizen")
else:
    print("Senior Citizen")
# Out:
# Your Age is -> 18
# Adult
